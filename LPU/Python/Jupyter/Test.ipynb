# %% [markdown]
# My First Notebook

# %%
def exp(time, money=10):
    time = time
    money = money
    print(f"You have spent Rs.{money} in the {time}")

exp("Morning")
exp("Afternoon", 50)
exp("Evening", 80)
# Out:
# You have spent Rs.10 in the Morning
# You have spent Rs.50 in the Afternoon
# You have spent Rs.80 in the Evening

# %%
#Sandbox1
title = input('Enter the title of the book: ')
author = input('Enter the name of the author of the book: ')
price = float(input('Enter the price of the book'))
stock_qnty = int(input("Enter Stock Quantitiy: "))
print(f"Information of the book:\nTitle: {title}\nAuthor: {author}\nPrice: {price}\nStock Quantity: {stock_qnty}")
# Out:
# Information of the book:
# Title: kk
# Author: hj
# Price: 8.99
# Stock Quantity: 8

# %%
#Sandbox2
print(f"Prize Distribution to Number of students: {53//8}\nLeft: {53%8}")
# Out:
# Prize Distribution to Number of students: 6
# Left: 5

# %%
#Sandbox3
user = int(input("Enter time in Seconds: "))
print(f"Total Time: {user}\nMinutes: {user//60}\nSeconds: {user%60}")
# Out:
# Total Time: 660
# Minutes: 11
# Seconds: 0

# %%
import Spending
import importlib

importlib.reload(Spending)
Spending.MorningSpend()
Spending.MorningSpend(60)
Spending.AfternoonSpend(80)
Spending.AfternoonSpend(60)
Spending.EveningSpend(100)
Spending.EveningSpend(200)
Spending.TotalSpend()
# Out:
# You spend Rs. 10 in the morning.
# You spend Rs. 60 in the morning.
# You spend Rs. 80 in the afternoon.
# You spend Rs. 60 in the afternoon.
# You spend Rs. 100 in the evening.
# You spend Rs. 200 in the evening.
# Your total spending for the day is: 510

# %%
# %%writefile demo.py
#It is used to create file in juypter notebook.

def add(a,b):
    return a+b
# Out:
# Overwriting demo.py

# %%
import demo
import importlib

importlib.reload(demo)

a = demo.add(5,6)

print("The sume is ", a)
# Out:
# The sume is  11

# %% [markdown]
# Data Structures in Python

# %%
listA = [2,3,4.5,6.9,"LPU","CAP776",5.79,6,7]
print(type(listA))
print(len(listA))
listB = [2,3,4.5,["LPU","CAP776","Vishal",[5,6,7],21326],5.6,2.9]
print(listB[1])
print(listB[3])
print(listB[3][1])
print(listB[3][3])
print(listB[3][3][2])
# Out:
# <class 'list'>
# 9
# 3
# ['LPU', 'CAP776', 'Vishal', [5, 6, 7], 21326]
# CAP776
# [5, 6, 7]
# 7
